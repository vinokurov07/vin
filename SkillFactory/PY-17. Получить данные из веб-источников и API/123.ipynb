# %%
import pandas as pd
solar_data = pd.read_csv('solarpower.csv')
solar_data.head()
index = solar_data.index
for i in index:
    if solar_data['cum_power'].loc[i] == -1:
        solar_data['cum_power'].loc[i] = (solar_data['cum_power'].loc[i-1]+solar_data['cum_power'].loc[i+1])/2
# Out:
# C:\Users\Lario\AppData\Local\Temp\ipykernel_17456\688953311.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   solar_data['cum_power'].loc[i] = (solar_data['cum_power'].loc[i-1]+solar_data['cum_power'].loc[i+1])/2
# C:\Users\Lario\AppData\Local\Temp\ipykernel_17456\688953311.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_data['cum_power'].loc[i] = (solar_data['cum_power'].loc[i-1]+solar_data['cum_power'].loc[i+1])/2
# C:\Users\Lario\AppData\Local\Temp\ipykernel_17456\688953311.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   solar_data['cum_power'].loc[i] = (solar_data['cum_power'].loc[i-1]+solar_data['cum_power'].loc[i+1])/2
# C:\Users\Lario\AppData\Local\Temp\ipykernel_17456\688953311.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_data['cum_power'].loc[i] = (solar_data['cum_power'].loc[i-1]+solar_data['cum_power'].loc[i+1])/2

# %%
solar_data['date'] = pd.to_datetime(solar_data['date'])
solar_data['year-month'] = solar_data['date'].dt.to_period('M')
display(solar_data)
solar_data['day_power'] = solar_data['cum_power'].diff()
df = solar_data.groupby(by=['year-month'],as_index=False).mean().round()
display(df)
# Out:
#           date  cum_power year-month
# 0   2017-01-01    20111.0    2017-01
# 1   2017-01-02    20112.0    2017-01
# 2   2017-01-03    20115.0    2017-01
# 3   2017-01-04    20117.0    2017-01
# 4   2017-01-05    20119.0    2017-01
# ..         ...        ...        ...
# 659 2018-10-22    28101.0    2018-10
# 660 2018-10-23    28109.0    2018-10
# 661 2018-10-24    28115.0    2018-10
# 662 2018-10-25    28117.0    2018-10
# 663 2018-10-26    28120.0    2018-10
#
# [664 rows x 3 columns]
#    year-month                date  cum_power  day_power
# 0     2017-01 2017-01-16 00:00:00    20153.0        3.0
# 1     2017-02 2017-02-14 12:00:00    20257.0        4.0
# 2     2017-03 2017-03-16 00:00:00    20445.0       11.0
# 3     2017-04 2017-04-15 12:00:00    20885.0       16.0
# 4     2017-05 2017-05-16 00:00:00    21408.0       19.0
# 5     2017-06 2017-06-15 12:00:00    22068.0       22.0
# 6     2017-07 2017-07-16 00:00:00    22667.0       18.0
# 7     2017-08 2017-08-16 00:00:00    23179.0       15.0
# 8     2017-09 2017-09-15 12:00:00    23573.0       12.0
# 9     2017-10 2017-10-16 00:00:00    23858.0        6.0
# 10    2017-11 2017-11-15 12:00:00    23999.0        3.0
# 11    2017-12 2017-12-16 00:00:00    24059.0        1.0
# 12    2018-01 2018-01-16 00:00:00    24104.0        2.0
# 13    2018-02 2018-02-14 12:00:00    24225.0        7.0
# 14    2018-03 2018-03-16 00:00:00    24461.0        9.0
# 15    2018-04 2018-04-15 12:00:00    24815.0       15.0
# 16    2018-05 2018-05-16 00:00:00    25387.0       21.0
# 17    2018-06 2018-06-15 12:00:00    25959.0       19.0
# 18    2018-07 2018-07-16 00:00:00    26625.0       22.0
# 19    2018-08 2018-08-16 00:00:00    27245.0       17.0
# 20    2018-09 2018-09-15 12:00:00    27692.0       14.0
# 21    2018-10 2018-10-13 12:00:00    28024.0        9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year-month  22 non-null     period[M]
#  1   date        22 non-null     datetime64[ns]
#  2   cum_power   22 non-null     float64
#  3   day_power   22 non-null     float64
# dtypes: datetime64[ns](1), float64(2), period[M](1)
# memory usage: 836.0 bytes

# %%
solar_data['year-month'] = solar_data['year-month'].to_timestamp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 solar_data['year-month'] = solar_data['year-month'].to_timestamp()
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:5983, in Series.to_timestamp(self, freq, how, copy)
#    5924 """
#    5925 Cast to DatetimeIndex of Timestamps, at *beginning* of period.
#    5926
#    (...)
#    5980 Freq: YE-JAN, dtype: int64
#    5981 """
#    5982 if not isinstance(self.index, PeriodIndex):
# -> 5983     raise TypeError(f"unsupported Type {type(self.index).__name__}")
#    5985 new_obj = self.copy(deep=copy and not using_copy_on_write())
#    5986 new_index = self.index.to_timestamp(freq=freq, how=how)
#
# TypeError: unsupported Type RangeIndex

# %%
import plotly
import plotly.express as px
fig = px.line(
    data_frame=df, #датафрейм
    x='year-month', #ось абсцисс
    y='day_power', #ось ординат
    height=500, #высота
    width=1000, #ширина
    title='Confirmed, Recovered, Deaths, Active cases over Time' #заголовок
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       2 import plotly.express as px
#       3 fig = px.line(
#       4     data_frame=df, #датафрейм
#       5     x='year-month', #ось абсцисс
#    (...)
#       9     title='Confirmed, Recovered, Deaths, Active cases over Time' #заголовок
#      10 )
# ---> 11 fig.show()
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:417, in show(fig, renderer, validate, **kwargs)
#     414 fig_dict = validate_coerce_fig_to_dict(fig, validate)
#     416 # Mimetype renderers
# --> 417 bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     418 if bundle:
#     419     if not ipython_display:
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:325, in RenderersConfig._build_mime_bundle(self, fig_dict, renderers_string, **kwargs)
#     322             if hasattr(renderer, k):
#     323                 setattr(renderer, k, v)
# --> 325         bundle.update(renderer.to_mimebundle(fig_dict))
#     327 return bundle
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_base_renderers.py:94, in PlotlyRenderer.to_mimebundle(self, fig_dict)
#      90 if config:
#      91     fig_dict["config"] = config
#      93 json_compatible_fig_dict = json.loads(
# ---> 94     to_json(fig_dict, validate=False, remove_uids=False)
#      95 )
#      97 return {"application/vnd.plotly.v1+json": json_compatible_fig_dict}
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_json.py:221, in to_json(fig, validate, pretty, remove_uids, engine)
#     218     for trace in fig_dict.get("data", []):
#     219         trace.pop("uid", None)
# --> 221 return to_json_plotly(fig_dict, pretty=pretty, engine=engine)
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_json.py:142, in to_json_plotly(plotly_object, pretty, engine)
#     137         opts["separators"] = (",", ":")
#     139     from _plotly_utils.utils import PlotlyJSONEncoder
#     141     return _safe(
# --> 142         json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts), _swap_json
#     143     )
#     144 elif engine == "orjson":
#     145     JsonConfig.validate_orjson()
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\_plotly_utils\utils.py:162, in PlotlyJSONEncoder.encode(self, o)
#     155 """
#     156 Load and then dump the result using parse_constant kwarg
#     157
#     158 Note that setting invalid separators will cause a failure at this step.
#     159
#     160 """
#     161 # this will raise errors in a normal-expected way
# --> 162 encoded_o = super(PlotlyJSONEncoder, self).encode(o)
#     163 # Brute force guessing whether NaN or Infinity values are in the string
#     164 # We catch false positive cases (e.g. strings such as titles, labels etc.)
#     165 # but this is ok since the intention is to skip the decoding / reencoding
#     166 # step when it's completely safe
#     168 if not ("NaN" in encoded_o or "Infinity" in encoded_o):
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\json\encoder.py:261, in JSONEncoder.iterencode(self, o, _one_shot)
#     256 else:
#     257     _iterencode = _make_iterencode(
#     258         markers, self.default, _encoder, indent, floatstr,
#     259         self.key_separator, self.item_separator, self.sort_keys,
#     260         self.skipkeys, _one_shot)
# --> 261 return _iterencode(o, 0)
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\site-packages\_plotly_utils\utils.py:239, in PlotlyJSONEncoder.default(self, obj)
#     237     except NotEncodable:
#     238         pass
# --> 239 return _json.JSONEncoder.default(self, obj)
#
# File c:\Users\Lario\AppData\Local\Programs\Python\Python313\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Period is not JSON serializable

# %%
solar_data['month'] = solar_data['date'].dt.month
solar_data['year'] = solar_data['date'].dt.year

df = solar_data.groupby(by=['year','month'])['day_power'].mean()
mask1 = solar_data['year'] == 2017
mask2 = solar_data['month'] == 3
display(solar_data[mask1&mask2]['day_power'].mean())
display(df)
# Out:
# np.float64(10.774193548387096)
# year  month
# 2017  1         3.233333
#       2         3.714286
#       3        10.774194
#       4        16.300000
#       5        19.000000
#       6        21.500000
#       7        18.129032
#       8        15.064516
#       9        11.533333
#       10        6.419355
#       11        3.233333
#       12        1.161290
# 2018  1         2.064516
#       2         6.928571
#       3         8.709677
#       4        14.633333
#       5        21.032258
#       6        18.766667
#       7        22.000000
#       8        17.096774
#       9        13.866667
#       10        9.000000
# Name: day_power, dtype: float64
